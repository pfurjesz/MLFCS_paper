# %%
from pathlib import Path
import sys

parent_dir = Path().resolve().parent
sys.path.append(str(parent_dir))

import numpy as np
import pandas as pd
from models.ensemble import TME_ensemble
from models.tme import deses                  
from models.tme import rmse, mae, mape, iw, nnll   
from data.preprocess import read_txn_data , preprocess_txn_data, compute_lob_features, \
    create_lob_dataset, merge_txn_and_lob
from models.deseasonalization import deses

# %%
cfg = {
    "data_split": {
        "train_size": 0.7,
        "validation_size": 0.1
    },
    "model_params": {
        "n_models": 10,
        "horizon": 100,
        "batch_size": 4096,
        "learning_rate": 0.001,
        "epochs": 10,
        "l2_lambda": 0.01  # L2 regularization strength
    }
}

# %% [markdown]
# # 1 min

# %%
freq='1min'
trx_df = read_txn_data(use_load=False)
lob_df = create_lob_dataset(use_load=False)
trx_df = preprocess_txn_data(trx_df,freq, fill_missing_ts=False)
df_raw = merge_txn_and_lob(trx_df, lob_df)

tme = TME_ensemble(df_raw, cfg)
tme.train()

# New visualization methods
tme.plot_learning_curves() 
tme.plot_variable_importance()

# Evaluation
tme.evaluate()
# Out:
# trx Data loaded successfully.
# preprocessed lob Data loaded successfully.
#
# Training model 1/10
# ep01  train 4.8651  val 4.6547
# ep02  train 3.9178  val 3.0693
# ep03  train 3.4140  val 2.8737
# ep04  train 3.2426  val 2.8323
# ep05  train 3.1489  val 2.7878
# ep06  train 3.0763  val 2.7628
# ep07  train 3.0160  val 2.7399
# ep08  train 2.9665  val 2.7212
# ep09  train 2.9213  val 2.7054
# ep10  train 2.8825  val 2.6882
#
# Training model 2/10
# ep01  train 4.9398  val 4.9739
# ep02  train 3.9465  val 3.0823
# ep03  train 3.3958  val 2.8675
# ep04  train 3.2356  val 2.8271
# ep05  train 3.1407  val 2.7961
# ep06  train 3.0710  val 2.7680
# ep07  train 3.0156  val 2.7431
# ep08  train 2.9636  val 2.7251
# ep09  train 2.9197  val 2.7025
# ep10  train 2.8814  val 2.6812
#
# Training model 3/10
# ep01  train 4.8333  val 4.4224
# ep02  train 3.8041  val 3.0287
# ep03  train 3.3631  val 2.8628
# ep04  train 3.2166  val 2.8192
# ep05  train 3.1264  val 2.7827
# ep06  train 3.0568  val 2.7598
# ep07  train 3.0006  val 2.7346
# ep08  train 2.9531  val 2.7159
# ep09  train 2.9092  val 2.6894
# ep10  train 2.8693  val 2.6772
#
# Training model 4/10
# ep01  train 4.8904  val 4.6678
# ep02  train 3.8682  val 3.0581
# ep03  train 3.3795  val 2.8748
# ep04  train 3.2250  val 2.8227
# ep05  train 3.1346  val 2.7884
# ep06  train 3.0668  val 2.7615
# ep07  train 3.0074  val 2.7403
# ep08  train 2.9583  val 2.7206
# ep09  train 2.9141  val 2.6998
# ep10  train 2.8752  val 2.6779
#
# Training model 5/10
# ep01  train 4.9016  val 4.7671
# ep02  train 3.9081  val 3.0342
# ep03  train 3.3837  val 2.8562
# ep04  train 3.2274  val 2.8198
# ep05  train 3.1370  val 2.7779
# ep06  train 3.0700  val 2.7621
# ep07  train 3.0108  val 2.7390
# ep08  train 2.9620  val 2.7204
# ep09  train 2.9195  val 2.6940
# ep10  train 2.8788  val 2.6795
#
# Training model 6/10
# ep01  train 4.8624  val 4.6392
# ep02  train 3.8774  val 3.0545
# ep03  train 3.3903  val 2.8676
# ep04  train 3.2322  val 2.8226
# ep05  train 3.1425  val 2.7874
# ep06  train 3.0719  val 2.7670
# ep07  train 3.0123  val 2.7450
# ep08  train 2.9629  val 2.7281
# ep09  train 2.9198  val 2.7062
# ep10  train 2.8804  val 2.6890
#
# Training model 7/10
# ep01  train 4.7602  val 4.2242
# ep02  train 3.7508  val 3.0026
# ep03  train 3.3455  val 2.8522
# ep04  train 3.2031  val 2.8143
# ep05  train 3.1163  val 2.7741
# ep06  train 3.0465  val 2.7514
# ep07  train 2.9920  val 2.7306
# ep08  train 2.9436  val 2.7097
# ep09  train 2.9016  val 2.6966
# ep10  train 2.8604  val 2.6780
#
# Training model 8/10
# ep01  train 4.9058  val 4.7550
# ep02  train 3.8909  val 3.0634
# ep03  train 3.3828  val 2.8669
# ep04  train 3.2308  val 2.8215
# ep05  train 3.1402  val 2.7937
# ep06  train 3.0700  val 2.7630
# ep07  train 3.0104  val 2.7439
# ep08  train 2.9606  val 2.7186
# ep09  train 2.9181  val 2.7036
# ep10  train 2.8798  val 2.6822
#
# Training model 9/10
# ep01  train 4.8696  val 4.6336
# ep02  train 3.8659  val 3.0293
# ep03  train 3.3727  val 2.8550
# ep04  train 3.2208  val 2.8155
# ep05  train 3.1282  val 2.7784
# ep06  train 3.0600  val 2.7552
# ep07  train 3.0056  val 2.7369
# ep08  train 2.9563  val 2.7170
# ep09  train 2.9117  val 2.6896
# ep10  train 2.8728  val 2.6784
#
# Training model 10/10
# ep01  train 4.7929  val 4.3072
# ep02  train 3.7766  val 2.9744
# ep03  train 3.3372  val 2.8407
# ep04  train 3.1982  val 2.8005
# ep05  train 3.1111  val 2.7676
# ep06  train 3.0446  val 2.7405
# ep07  train 2.9880  val 2.7263
# ep08  train 2.9405  val 2.7107
# ep09  train 2.8964  val 2.6936
# ep10  train 2.8587  val 2.6726
#
# Selected 10 best models out of 10
# Validation performance of selected models:
# Model 10: 2.6726
# Model 3: 2.6772
# Model 4: 2.6779
# Model 7: 2.6780
# Model 9: 2.6784
# Model 5: 2.6795
# Model 2: 2.6812
# Model 8: 2.6822
# Model 1: 2.6882
# Model 6: 2.6890
# Metric     |      Value
# -----------------------
# RMSE         |      11.73
# MAE           |       4.43
# R²             |     0.0107
# MAPE (%)  |     187.57
# Coverage  |       80.4 %
# IW             |      51.04
# NNLL         |     4.9464
# (array([1.61345043e-03, 5.79489520e-01, 1.00035343e-03, ...,
#         1.52989072e+00, 9.35145751e-01, 9.83765599e-01]),
#  array([6.90637896, 2.95877713, 2.69808932, ..., 3.49237734, 3.11603979,
#         2.03175483]))

# %% [markdown]
# # 5 min

# %%
freq='5min'
trx_df = read_txn_data(use_load=False)
lob_df = create_lob_dataset(use_load=False)
trx_df = preprocess_txn_data(trx_df,freq, fill_missing_ts=False)
df_raw = merge_txn_and_lob(trx_df, lob_df)

tme = TME_ensemble(df_raw, cfg)
tme.train()

# New visualization methods
tme.plot_learning_curves() 
tme.plot_variable_importance()

# Evaluation
tme.evaluate()
# Out:
# trx Data loaded successfully.
# preprocessed lob Data loaded successfully.
#
# Training model 1/10
# ep01  train 2.4194  val 3.0583
# ep02  train 2.3935  val 2.9804
# ep03  train 2.3529  val 2.8606
# ep04  train 2.2937  val 2.7024
# ep05  train 2.2151  val 2.5275
# ep06  train 2.1468  val 2.3713
# ep07  train 2.0730  val 2.2659
# ep08  train 2.0345  val 2.2198
# ep09  train 2.0057  val 2.2104
# ep10  train 1.9843  val 2.2150
#
# Training model 2/10
# ep01  train 2.3997  val 3.0636
# ep02  train 2.3946  val 2.9972
# ep03  train 2.3283  val 2.8933
# ep04  train 2.3015  val 2.7514
# ep05  train 2.2270  val 2.5811
# ep06  train 2.1619  val 2.4125
# ep07  train 2.1004  val 2.2846
# ep08  train 2.0523  val 2.2190
# ep09  train 2.0367  val 2.1987
# ep10  train 2.0017  val 2.1989
#
# Training model 3/10
# ep01  train 2.4139  val 3.0469
# ep02  train 2.3832  val 2.9550
# ep03  train 2.3276  val 2.8234
# ep04  train 2.2889  val 2.6592
# ep05  train 2.1823  val 2.4848
# ep06  train 2.1209  val 2.3399
# ep07  train 2.0793  val 2.2481
# ep08  train 2.0297  val 2.2110
# ep09  train 2.0068  val 2.2049
# ep10  train 1.9796  val 2.2135
#
# Training model 4/10
# ep01  train 2.4301  val 3.0275
# ep02  train 2.3660  val 2.9131
# ep03  train 2.3198  val 2.7594
# ep04  train 2.2425  val 2.5876
# ep05  train 2.1600  val 2.4301
# ep06  train 2.0826  val 2.3153
# ep07  train 2.0358  val 2.2575
# ep08  train 2.0003  val 2.2394
# ep09  train 1.9757  val 2.2334
# ep10  train 1.9604  val 2.2289
#
# Training model 5/10
# ep01  train 2.4236  val 3.0527
# ep02  train 2.3823  val 2.9706
# ep03  train 2.3361  val 2.8505
# ep04  train 2.2957  val 2.6952
# ep05  train 2.2095  val 2.5241
# ep06  train 2.1544  val 2.3697
# ep07  train 2.0853  val 2.2609
# ep08  train 2.0502  val 2.2073
# ep09  train 2.0265  val 2.1952
# ep10  train 1.9871  val 2.2010
#
# Training model 6/10
# ep01  train 2.4209  val 3.0735
# ep02  train 2.3969  val 3.0161
# ep03  train 2.3560  val 2.9156
# ep04  train 2.3184  val 2.7713
# ep05  train 2.2563  val 2.5960
# ep06  train 2.1806  val 2.4246
# ep07  train 2.1080  val 2.2991
# ep08  train 2.0443  val 2.2314
# ep09  train 2.0226  val 2.2123
# ep10  train 1.9827  val 2.2177
#
# Training model 7/10
# ep01  train 2.4153  val 3.0715
# ep02  train 2.3953  val 3.0129
# ep03  train 2.3608  val 2.9119
# ep04  train 2.2939  val 2.7625
# ep05  train 2.2423  val 2.5817
# ep06  train 2.1435  val 2.4080
# ep07  train 2.0845  val 2.2866
# ep08  train 2.0455  val 2.2258
# ep09  train 2.0187  val 2.2115
# ep10  train 1.9873  val 2.2197
#
# Training model 8/10
# ep01  train 2.4228  val 3.0480
# ep02  train 2.3945  val 2.9614
# ep03  train 2.3525  val 2.8359
# ep04  train 2.2874  val 2.6744
# ep05  train 2.2009  val 2.4986
# ep06  train 2.1181  val 2.3472
# ep07  train 2.0723  val 2.2526
# ep08  train 2.0454  val 2.2131
# ep09  train 2.0138  val 2.2048
# ep10  train 1.9762  val 2.2088
#
# Training model 9/10
# ep01  train 2.4196  val 3.0623
# ep02  train 2.4097  val 2.9875
# ep03  train 2.3557  val 2.8691
# ep04  train 2.2832  val 2.7112
# ep05  train 2.2206  val 2.5338
# ep06  train 2.1382  val 2.3769
# ep07  train 2.0739  val 2.2731
# ep08  train 2.0333  val 2.2280
# ep09  train 2.0079  val 2.2217
# ep10  train 1.9793  val 2.2292
#
# Training model 10/10
# ep01  train 2.4358  val 3.0541
# ep02  train 2.3924  val 2.9680
# ep03  train 2.3383  val 2.8386
# ep04  train 2.2782  val 2.6717
# ep05  train 2.1931  val 2.4944
# ep06  train 2.1158  val 2.3483
# ep07  train 2.0794  val 2.2594
# ep08  train 2.0232  val 2.2243
# ep09  train 1.9963  val 2.2196
# ep10  train 1.9647  val 2.2256
#
# Selected 10 best models out of 10
# Validation performance of selected models:
# Model 5: 2.1952
# Model 2: 2.1987
# Model 8: 2.2048
# Model 3: 2.2049
# Model 1: 2.2104
# Model 7: 2.2115
# Model 6: 2.2123
# Model 10: 2.2196
# Model 9: 2.2217
# Model 4: 2.2289
# Metric     |      Value
# -----------------------
# RMSE         |      35.78
# MAE           |      18.68
# R²             |    -0.0266
# MAPE (%)  |     432.49
# Coverage  |       76.0 %
# IW             |      39.69
# NNLL         |     2.8889
# (array([ 6.93566508, 15.83377776,  8.48661181, ...,  2.35188444,
#          7.64728898,  4.93160051]),
#  array([28.57560687, 28.53195259, 24.69248114, ..., 19.16249927,
#         15.94104801, 19.18855108]))

# %% [markdown]
# # 10 min

# %%
freq='10min'
trx_df = read_txn_data(use_load=False)
lob_df = create_lob_dataset(use_load=False)
trx_df = preprocess_txn_data(trx_df,freq, fill_missing_ts=False)
df_raw = merge_txn_and_lob(trx_df, lob_df)

tme = TME_ensemble(df_raw, cfg)
tme.train()

# New visualization methods
tme.plot_learning_curves() 
tme.plot_variable_importance()

# Evaluation
tme.evaluate()
# Out:
# trx Data loaded successfully.
# preprocessed lob Data loaded successfully.
#
# Training model 1/10
# ep01  train 1.9219  val 2.2060
# ep02  train 1.9141  val 2.1932
# ep03  train 1.9023  val 2.1766
# ep04  train 1.8923  val 2.1556
# ep05  train 1.8781  val 2.1301
# ep06  train 1.8607  val 2.0999
# ep07  train 1.8575  val 2.0654
# ep08  train 1.8291  val 2.0280
# ep09  train 1.8240  val 1.9887
# ep10  train 1.7986  val 1.9497
#
# Training model 2/10
# ep01  train 1.9169  val 2.2089
# ep02  train 1.9150  val 2.1994
# ep03  train 1.9074  val 2.1865
# ep04  train 1.8983  val 2.1695
# ep05  train 1.8854  val 2.1482
# ep06  train 1.8691  val 2.1221
# ep07  train 1.8538  val 2.0917
# ep08  train 1.8469  val 2.0581
# ep09  train 1.8265  val 2.0213
# ep10  train 1.8130  val 1.9834
#
# Training model 3/10
# ep01  train 1.9192  val 2.2054
# ep02  train 1.9130  val 2.1917
# ep03  train 1.9029  val 2.1743
# ep04  train 1.9005  val 2.1526
# ep05  train 1.8778  val 2.1266
# ep06  train 1.8693  val 2.0963
# ep07  train 1.8479  val 2.0622
# ep08  train 1.8303  val 2.0249
# ep09  train 1.8232  val 1.9862
# ep10  train 1.7994  val 1.9481
#
# Training model 4/10
# ep01  train 1.9259  val 2.2084
# ep02  train 1.9093  val 2.1980
# ep03  train 1.9036  val 2.1840
# ep04  train 1.8926  val 2.1658
# ep05  train 1.8881  val 2.1428
# ep06  train 1.8676  val 2.1150
# ep07  train 1.8582  val 2.0829
# ep08  train 1.8310  val 2.0468
# ep09  train 1.8253  val 2.0080
# ep10  train 1.8044  val 1.9686
#
# Training model 5/10
# ep01  train 1.9220  val 2.2020
# ep02  train 1.9134  val 2.1851
# ep03  train 1.8921  val 2.1647
# ep04  train 1.8765  val 2.1405
# ep05  train 1.8727  val 2.1123
# ep06  train 1.8553  val 2.0807
# ep07  train 1.8350  val 2.0465
# ep08  train 1.8228  val 2.0109
# ep09  train 1.7993  val 1.9747
# ep10  train 1.7816  val 1.9389
#
# Training model 6/10
# ep01  train 1.9236  val 2.2067
# ep02  train 1.9138  val 2.1933
# ep03  train 1.9034  val 2.1756
# ep04  train 1.8861  val 2.1535
# ep05  train 1.8776  val 2.1268
# ep06  train 1.8640  val 2.0953
# ep07  train 1.8482  val 2.0600
# ep08  train 1.8279  val 2.0220
# ep09  train 1.8144  val 1.9830
# ep10  train 1.7879  val 1.9454
#
# Training model 7/10
# ep01  train 1.9122  val 2.2056
# ep02  train 1.9082  val 2.1922
# ep03  train 1.9011  val 2.1748
# ep04  train 1.8962  val 2.1530
# ep05  train 1.8777  val 2.1266
# ep06  train 1.8654  val 2.0960
# ep07  train 1.8490  val 2.0614
# ep08  train 1.8326  val 2.0240
# ep09  train 1.8122  val 1.9856
# ep10  train 1.8001  val 1.9474
#
# Training model 8/10
# ep01  train 1.9234  val 2.2037
# ep02  train 1.9170  val 2.1885
# ep03  train 1.8947  val 2.1695
# ep04  train 1.8868  val 2.1467
# ep05  train 1.8707  val 2.1202
# ep06  train 1.8550  val 2.0901
# ep07  train 1.8478  val 2.0570
# ep08  train 1.8264  val 2.0214
# ep09  train 1.8087  val 1.9849
# ep10  train 1.7927  val 1.9485
#
# Training model 9/10
# ep01  train 1.9292  val 2.2101
# ep02  train 1.9136  val 2.2022
# ep03  train 1.9096  val 2.1916
# ep04  train 1.8942  val 2.1774
# ep05  train 1.8882  val 2.1590
# ep06  train 1.8792  val 2.1360
# ep07  train 1.8650  val 2.1085
# ep08  train 1.8489  val 2.0766
# ep09  train 1.8373  val 2.0416
# ep10  train 1.8165  val 2.0047
#
# Training model 10/10
# ep01  train 1.9172  val 2.2080
# ep02  train 1.9138  val 2.1975
# ep03  train 1.9040  val 2.1835
# ep04  train 1.8979  val 2.1650
# ep05  train 1.8893  val 2.1418
# ep06  train 1.8777  val 2.1136
# ep07  train 1.8581  val 2.0807
# ep08  train 1.8380  val 2.0442
# ep09  train 1.8233  val 2.0053
# ep10  train 1.8004  val 1.9655
#
# Selected 10 best models out of 10
# Validation performance of selected models:
# Model 5: 1.9389
# Model 6: 1.9454
# Model 7: 1.9474
# Model 3: 1.9481
# Model 8: 1.9485
# Model 1: 1.9497
# Model 10: 1.9655
# Model 4: 1.9686
# Model 2: 1.9834
# Model 9: 2.0047
# Metric     |      Value
# -----------------------
# RMSE         |      58.30
# MAE           |      35.85
# R²             |    -0.0061
# MAPE (%)  |     465.24
# Coverage  |       68.5 %
# IW             |      74.97
# NNLL         |     2.4245
# (array([219.10196249,  16.76405125,  48.48693492, ...,  19.63661188,
#           6.01488119,  12.57888856]),
#  array([41.79180823, 43.59406872, 33.91436091, ..., 50.87662075,
#         41.63707603, 41.53103205]))

# %% [markdown]
# # Cross Validation

# %%
freq='10min'
trx_df = read_txn_data(use_load=False)
lob_df = create_lob_dataset(use_load=False)
trx_df = preprocess_txn_data(trx_df,freq, fill_missing_ts=False)
df_raw = merge_txn_and_lob(trx_df, lob_df)
df_deses, _ = deses(df_raw)
# Out:
# trx Data loaded successfully.
# preprocessed lob Data loaded successfully.
# C:\Users\peter\.0\codes\eth\Komplex\Final\models\deseasonalization.py:44: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rest['mean_volume'].replace(0, 1e-8, inplace=True)

# %%
from models.ensemble_cv import TME_ensemble_CV


cfg = {
    "data_split": {
        "n_splits": 2,
        "test_size": 0.2
    },
    "model_params": {
        "horizon": 50,
        "batch_size": 4096,
        "learning_rate": 0.1,
        "epochs": 3,
        "n_models": 10,
        "l2_lambda": 0.1
    }
}


# Initialize and train
model = TME_ensemble_CV(df_deses, cfg)
model.train()

# Evaluate and visualize
y_true, y_pred = model.evaluate()
model.plot_learning_curves()
model.plot_variable_importance()

# Save model
#model.save("tme_ensemble_cv.pth")

# Later load and use
# loaded_model = TME_ensemble_CV.load("tme_ensemble_cv.pth", df)
# Out:
# === Training Fold 1/2 ===
#
# Training model 1/10
# ep01  train 3.4180  val 1.6381
# ep02  train 2.6117  val 1.5021
# ep03  train 3.1410  val 1.4684
#
# Training model 2/10
# ep01  train 3.5337  val 1.3885
# ep02  train 2.8503  val 1.9405
# ep03  train 3.2745  val 1.6979
#
# Training model 3/10
# ep01  train 3.2454  val 1.5441
# ep02  train 2.6633  val 2.0545
# ep03  train 3.4011  val 1.3919
#
# Training model 4/10
# ep01  train 3.4950  val 1.9405
# ep02  train 2.8563  val 1.9472
# ep03  train 3.8558  val 1.5125
#
# Training model 5/10
# ep01  train 3.8728  val 1.7792
# ep02  train 3.4378  val 1.5308
# ep03  train 3.3938  val 1.4664
#
# Training model 6/10
# ep01  train 3.1054  val 1.5034
# ep02  train 2.8037  val 1.7438
# ep03  train 3.2622  val 1.6495
#
# Training model 7/10
# ep01  train 3.1751  val 1.5883
# ep02  train 2.4150  val 1.4531
# ep03  train 3.2736  val 1.5071
#
# Training model 8/10
# ep01  train 3.5283  val 1.3987
# ep02  train 2.2477  val 1.9103
# ep03  train 3.2577  val 1.3852
#
# Training model 9/10
# ep01  train 3.1921  val 1.5550
# ep02  train 2.4121  val 2.1474
# ep03  train 3.3593  val 1.4047
#
# Training model 10/10
# ep01  train 3.0825  val 1.4357
# ep02  train 2.3795  val 1.9082
# ep03  train 3.1351  val 1.7444
#
# === Training Fold 2/2 ===
#
# Training model 1/10
# ep01  train 2.8321  val 1.8884
# ep02  train 2.7503  val 1.9499
# ep03  train 1.8993  val 1.9150
#
# Training model 2/10
# ep01  train 2.8346  val 2.1836
# ep02  train 2.7322  val 1.8129
# ep03  train 2.0026  val 1.9820
#
# Training model 3/10
# ep01  train 2.7885  val 2.0736
# ep02  train 2.6346  val 2.2454
# ep03  train 1.9374  val 1.8794
#
# Training model 4/10
# ep01  train 2.6903  val 2.3812
# ep02  train 2.7547  val 1.8597
# ep03  train 1.9006  val 2.0059
#
# Training model 5/10
# ep01  train 2.9214  val 2.3041
# ep02  train 2.7429  val 1.9020
# ep03  train 2.0045  val 1.9681
#
# Training model 6/10
# ep01  train 2.8446  val 2.1741
# ep02  train 2.7458  val 1.8173
# ep03  train 2.0508  val 1.9727
#
# Training model 7/10
# ep01  train 2.7356  val 1.8587
# ep02  train 2.7148  val 1.9222
# ep03  train 1.8880  val 1.8852
#
# Training model 8/10
# ep01  train 2.7550  val 2.2594
# ep02  train 2.7135  val 1.9128
# ep03  train 1.9830  val 1.9150
#
# Training model 9/10
# ep01  train 2.8379  val 1.8631
# ep02  train 2.7217  val 1.8355
# ep03  train 2.0012  val 1.8485
#
# Training model 10/10
# ep01  train 2.8681  val 2.3385
# ep02  train 2.8976  val 2.1079
# ep03  train 1.9425  val 1.9122
#
# Training completed across all folds!
# Metric     |      Value
# -----------------------
# RMSE         |      57.10
# MAE           |      27.01
# R²             |     0.0252
# MAPE (%)  |     254.26
# Coverage  |       88.7 %
# IW             |      68.16
# NNLL         |     1.7251
